# %% [markdown]
# <a href="https://colab.research.google.com/github/yampatiharsha/2400031601-fsadendexam/blob/main/Performance1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-632ff4a3-97af-4ec1-bdb7-2f0c43b9266d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-632ff4a3-97af-4ec1-bdb7-2f0c43b9266d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
df = pd.read_csv('rearranged_sales_dataset.csv')

df.head()
print("Rows, Columns:", df.shape)
print(df.columns.tolist())
df.info()
# Out:
# Rows, Columns: (9, 7)
# ['OrderID', 'Product', 'Category', 'Sales', 'Quantity', 'Profit', 'Date']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   9 non-null      int64
#  1   Product   9 non-null      object
#  2   Category  9 non-null      object
#  3   Sales     9 non-null      int64
#  4   Quantity  9 non-null      int64
#  5   Profit    9 non-null      int64
#  6   Date      9 non-null      object
# dtypes: int64(4), object(3)
# memory usage: 636.0+ bytes

# %%
df.isnull().sum()
# Out:
# OrderID     0
# Product     0
# Category    0
# Sales       0
# Quantity    0
# Profit      0
# Date        0
# dtype: int64

# %%
df.describe()
# Out:
#         OrderID         Sales   Quantity       Profit
# count  9.000000      9.000000   9.000000     9.000000
# mean   5.000000  22222.222222   3.555556  4111.111111
# std    2.738613  16445.195178   2.788867  2902.345795
# min    1.000000   5000.000000   1.000000  1000.000000
# 25%    3.000000  10000.000000   2.000000  2000.000000
# 50%    5.000000  15000.000000   3.000000  3000.000000
# 75%    7.000000  30000.000000   4.000000  6000.000000
# max    9.000000  50000.000000  10.000000  9000.000000

# %%
total_sales = df['Sales'].sum()
total_profit = df['Profit'].sum()
total_orders = len(df)

print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
print("Total Orders:", total_orders)
# Out:
# Total Sales: 200000
# Total Profit: 37000
# Total Orders: 9

# %%
product_sales = df.groupby('Product')['Sales'].sum()

product_sales.sort_values(ascending=False)
# Out:
# Product
# Laptop        75000
# Phone         75000
# Table         27000
# Chair         18000
# Headphones     5000
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(10,5))

product_sales.sort_values(ascending=False).plot(kind='bar')

plt.title('Sales by Product')
plt.xlabel('Product')
plt.ylabel('Sales')

plt.show()
